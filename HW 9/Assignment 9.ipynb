# %%
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("impr.csv")

# %%
data
# Out:
#      password  value  strength  font_size  Length
# 0    password   6.91         8         11       8
# 1      123456  18.52         4          8       6
# 2    12345678   1.29         4          8       8
# 3        1234  11.11         4          8       4
# 4      qwerty   3.72         8         11       6
# ..        ...    ...       ...        ...     ...
# 495    reddog   3.72         6         10       6
# 496  alexande   6.91         9         12       8
# 497   college   3.19         7         11       7
# 498    jester   3.72         7         11       6
# 499  passw0rd  92.27        28         21       8
#
# [500 rows x 5 columns]

# %%
new = data.groupby(['font_size','strength']).size().reset_index()

# %%
new.columns = ['font_size','strength',"density"]

# %%
new
# Out:
#     font_size  strength  density
# 0           0         0       30
# 1           4         1        5
# 2           6         2        2
# 3           7         3        7
# 4           8         4       29
# 5           9         5       17
# 6          10         6       76
# 7          11         7      101
# 8          11         8      162
# 9          12         9       46
# 10         13        10       10
# 11         17        19        1
# 12         18        21        1
# 13         20        25        1
# 14         21        28        1
# 15         23        32        2
# 16         23        34        1
# 17         24        35        1
# 18         24        36        3
# 19         25        38        1
# 20         27        46        2
# 21         28        48        1

# %%
sns.pairplot(data)
